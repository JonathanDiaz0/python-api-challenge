# %% [markdown]
# # WeatherPy
#
# ---
#
# ## Starter Code to Generate Random Geographic Coordinates and a List of Cities

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Impor the OpenWeatherMap API key
from api_keys import weather_api_key

# Import citipy to determine the cities based on latitude and longitude

from citipy import citipy

# %%
# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
# Out:
# Number of cities in the list: 630

# %% [markdown]
# ---

# %% [markdown]
# ## Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude
#
# ### Use the OpenWeatherMap API to retrieve weather data from the cities list generated in the started code

# %%
# Set the API base URL
url = f"http://api.openweathermap.org/data/2.5/weather?units=metric&appid={weather_api_key}"
# Define an empty list to fetch the weather data for each city
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    city_url = f"{url}&q={city}"
    
    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        city_weather = requests.get(city_url).json()

        # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_date = city_weather["dt"]

        # Append the City information into city_data list
        city_data.append({"City": city, 
                          "Lat": city_lat, 
                          "Lng": city_lng, 
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass
              
# Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | urucara
# Processing Record 2 of Set 1 | ushuaia
# Processing Record 3 of Set 1 | albany
# Processing Record 4 of Set 1 | cidreira
# Processing Record 5 of Set 1 | punta arenas
# Processing Record 6 of Set 1 | vaini
# Processing Record 7 of Set 1 | palotina
# Processing Record 8 of Set 1 | iqaluit
# Processing Record 9 of Set 1 | barrow
# Processing Record 10 of Set 1 | yellowknife
# Processing Record 11 of Set 1 | hobart
# Processing Record 12 of Set 1 | puerto ayora
# Processing Record 13 of Set 1 | mahebourg
# Processing Record 14 of Set 1 | riviere-au-renard
# Processing Record 15 of Set 1 | amderma
# City not found. Skipping...
# Processing Record 16 of Set 1 | atar
# Processing Record 17 of Set 1 | kodiak
# Processing Record 18 of Set 1 | norman wells
# Processing Record 19 of Set 1 | kankon
# Processing Record 20 of Set 1 | mataura
# Processing Record 21 of Set 1 | hermanus
# Processing Record 22 of Set 1 | laishevo
# Processing Record 23 of Set 1 | dunedin
# Processing Record 24 of Set 1 | bengkulu
# Processing Record 25 of Set 1 | faya
# Processing Record 26 of Set 1 | qaanaaq
# Processing Record 27 of Set 1 | dudinka
# Processing Record 28 of Set 1 | rikitea
# Processing Record 29 of Set 1 | saldanha
# Processing Record 30 of Set 1 | castro
# Processing Record 31 of Set 1 | bredasdorp
# Processing Record 32 of Set 1 | dingle
# Processing Record 33 of Set 1 | boa vista
# Processing Record 34 of Set 1 | kiunga
# Processing Record 35 of Set 1 | magway
# Processing Record 36 of Set 1 | busselton
# Processing Record 37 of Set 1 | tura
# Processing Record 38 of Set 1 | encruzilhada do sul
# Processing Record 39 of Set 1 | sento se
# City not found. Skipping...
# Processing Record 40 of Set 1 | sioux lookout
# Processing Record 41 of Set 1 | sainte-rose
# Processing Record 42 of Set 1 | saint george
# Processing Record 43 of Set 1 | buin
# Processing Record 44 of Set 1 | mar del plata
# Processing Record 45 of Set 1 | kapaa
# Processing Record 46 of Set 1 | ijaki
# City not found. Skipping...
# Processing Record 47 of Set 1 | hefei
# Processing Record 48 of Set 1 | santa vitoria do palmar
# Processing Record 49 of Set 1 | avarua
# Processing Record 50 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 0 of Set 2 | upernavik
# Processing Record 1 of Set 2 | mayumba
# Processing Record 2 of Set 2 | sentyabrskiy
# City not found. Skipping...
# Processing Record 3 of Set 2 | san quintin
# Processing Record 4 of Set 2 | asyut
# Processing Record 5 of Set 2 | bathsheba
# Processing Record 6 of Set 2 | christchurch
# Processing Record 7 of Set 2 | longyearbyen
# Processing Record 8 of Set 2 | cheuskiny
# City not found. Skipping...
# Processing Record 9 of Set 2 | rorvik
# Processing Record 10 of Set 2 | jinchengjiang
# City not found. Skipping...
# Processing Record 11 of Set 2 | honningsvag
# Processing Record 12 of Set 2 | coahuayana
# Processing Record 13 of Set 2 | bluff
# Processing Record 14 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 15 of Set 2 | ierapetra
# Processing Record 16 of Set 2 | thompson
# Processing Record 17 of Set 2 | gari
# Processing Record 18 of Set 2 | ouadda
# Processing Record 19 of Set 2 | miri
# Processing Record 20 of Set 2 | carnarvon
# Processing Record 21 of Set 2 | chuy
# Processing Record 22 of Set 2 | cockburn harbour
# City not found. Skipping...
# Processing Record 23 of Set 2 | matara
# Processing Record 24 of Set 2 | troitskoye
# Processing Record 25 of Set 2 | kruisfontein
# Processing Record 26 of Set 2 | prieska
# Processing Record 27 of Set 2 | padang
# Processing Record 28 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 29 of Set 2 | kavieng
# Processing Record 30 of Set 2 | talnakh
# Processing Record 31 of Set 2 | ndioum
# Processing Record 32 of Set 2 | sorland
# Processing Record 33 of Set 2 | sinnamary
# Processing Record 34 of Set 2 | pimentel
# Processing Record 35 of Set 2 | lavrentiya
# Processing Record 36 of Set 2 | ilulissat
# Processing Record 37 of Set 2 | khasan
# Processing Record 38 of Set 2 | saint-philippe
# Processing Record 39 of Set 2 | sao joao da barra
# Processing Record 40 of Set 2 | cape town
# Processing Record 41 of Set 2 | georgetown
# Processing Record 42 of Set 2 | dikson
# Processing Record 43 of Set 2 | adrasmon
# Processing Record 44 of Set 2 | kachiry
# Processing Record 45 of Set 2 | bayir
# Processing Record 46 of Set 2 | soc trang
# Processing Record 47 of Set 2 | gravdal
# Processing Record 48 of Set 2 | bethel
# Processing Record 49 of Set 2 | attawapiskat
# City not found. Skipping...
# Processing Record 0 of Set 3 | karla
# Processing Record 1 of Set 3 | aksarka
# Processing Record 2 of Set 3 | fengrun
# Processing Record 3 of Set 3 | lebu
# Processing Record 4 of Set 3 | andros town
# Processing Record 5 of Set 3 | tuktoyaktuk
# Processing Record 6 of Set 3 | hihifo
# City not found. Skipping...
# Processing Record 7 of Set 3 | cairns
# Processing Record 8 of Set 3 | sofiysk
# City not found. Skipping...
# Processing Record 9 of Set 3 | batticaloa
# Processing Record 10 of Set 3 | kudahuvadhoo
# Processing Record 11 of Set 3 | narsaq
# Processing Record 12 of Set 3 | rawson
# Processing Record 13 of Set 3 | hithadhoo
# Processing Record 14 of Set 3 | airai
# Processing Record 15 of Set 3 | antalaha
# Processing Record 16 of Set 3 | grahamstown
# Processing Record 17 of Set 3 | margate
# Processing Record 18 of Set 3 | rieti
# Processing Record 19 of Set 3 | esmeralda
# Processing Record 20 of Set 3 | jamestown
# Processing Record 21 of Set 3 | sutto
# Processing Record 22 of Set 3 | lago da pedra
# Processing Record 23 of Set 3 | ilo
# Processing Record 24 of Set 3 | abaete
# Processing Record 25 of Set 3 | eenhana
# Processing Record 26 of Set 3 | hanna
# Processing Record 27 of Set 3 | hilo
# Processing Record 28 of Set 3 | hammerfest
# Processing Record 29 of Set 3 | mildura
# Processing Record 30 of Set 3 | tessalit
# Processing Record 31 of Set 3 | pisco
# Processing Record 32 of Set 3 | kavaratti
# Processing Record 33 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 34 of Set 3 | new norfolk
# Processing Record 35 of Set 3 | bambous virieux
# Processing Record 36 of Set 3 | sitka
# Processing Record 37 of Set 3 | fort nelson
# Processing Record 38 of Set 3 | hami
# Processing Record 39 of Set 3 | economy
# Processing Record 40 of Set 3 | peta
# Processing Record 41 of Set 3 | husavik
# Processing Record 42 of Set 3 | saleaula
# City not found. Skipping...
# Processing Record 43 of Set 3 | waipawa
# Processing Record 44 of Set 3 | baneh
# Processing Record 45 of Set 3 | victoria
# Processing Record 46 of Set 3 | kikwit
# Processing Record 47 of Set 3 | bon accord
# Processing Record 48 of Set 3 | umzimvubu
# City not found. Skipping...
# Processing Record 49 of Set 3 | esperance
# Processing Record 0 of Set 4 | keti bandar
# Processing Record 1 of Set 4 | kilindoni
# Processing Record 2 of Set 4 | el reno
# Processing Record 3 of Set 4 | solnechnyy
# Processing Record 4 of Set 4 | rio gallegos
# Processing Record 5 of Set 4 | tazovskiy
# Processing Record 6 of Set 4 | kerchevskiy
# Processing Record 7 of Set 4 | hovd
# Processing Record 8 of Set 4 | los llanos de aridane
# Processing Record 9 of Set 4 | vyartsilya
# Processing Record 10 of Set 4 | atuona
# Processing Record 11 of Set 4 | pevek
# Processing Record 12 of Set 4 | korla
# Processing Record 13 of Set 4 | cockburn town
# Processing Record 14 of Set 4 | beringovskiy
# Processing Record 15 of Set 4 | poum
# Processing Record 16 of Set 4 | nantucket
# Processing Record 17 of Set 4 | visby
# Processing Record 18 of Set 4 | rayadrug
# Processing Record 19 of Set 4 | port alfred
# Processing Record 20 of Set 4 | mys shmidta
# City not found. Skipping...
# Processing Record 21 of Set 4 | laguna
# Processing Record 22 of Set 4 | ihosy
# Processing Record 23 of Set 4 | lata
# Processing Record 24 of Set 4 | ouallam
# Processing Record 25 of Set 4 | tumannyy
# City not found. Skipping...
# Processing Record 26 of Set 4 | khatanga
# Processing Record 27 of Set 4 | tabiauea
# City not found. Skipping...
# Processing Record 28 of Set 4 | loandjili
# Processing Record 29 of Set 4 | arraial do cabo
# Processing Record 30 of Set 4 | pangnirtung
# Processing Record 31 of Set 4 | vallenar
# Processing Record 32 of Set 4 | chaman
# Processing Record 33 of Set 4 | harper
# Processing Record 34 of Set 4 | andira
# Processing Record 35 of Set 4 | san esteban
# Processing Record 36 of Set 4 | nikolskoye
# Processing Record 37 of Set 4 | xichang
# Processing Record 38 of Set 4 | sumbe
# Processing Record 39 of Set 4 | grindavik
# Processing Record 40 of Set 4 | walvis bay
# Processing Record 41 of Set 4 | pedernales
# Processing Record 42 of Set 4 | birao
# Processing Record 43 of Set 4 | severo-yeniseyskiy
# Processing Record 44 of Set 4 | yangzhou
# Processing Record 45 of Set 4 | hasaki
# Processing Record 46 of Set 4 | arzgir
# Processing Record 47 of Set 4 | inverell
# Processing Record 48 of Set 4 | zhigalovo
# Processing Record 49 of Set 4 | ahipara
# Processing Record 0 of Set 5 | butaritari
# Processing Record 1 of Set 5 | rosetta
# Processing Record 2 of Set 5 | alamogordo
# Processing Record 3 of Set 5 | vanimo
# Processing Record 4 of Set 5 | lakselv
# Processing Record 5 of Set 5 | ostrovnoy
# Processing Record 6 of Set 5 | nizhneyansk
# City not found. Skipping...
# Processing Record 7 of Set 5 | toora-khem
# Processing Record 8 of Set 5 | cayenne
# Processing Record 9 of Set 5 | pacific grove
# Processing Record 10 of Set 5 | tsihombe
# City not found. Skipping...
# Processing Record 11 of Set 5 | tasiilaq
# Processing Record 12 of Set 5 | emerald
# Processing Record 13 of Set 5 | palmer
# Processing Record 14 of Set 5 | burnie
# Processing Record 15 of Set 5 | hutchinson
# Processing Record 16 of Set 5 | glenwood springs
# Processing Record 17 of Set 5 | chokurdakh
# Processing Record 18 of Set 5 | quatre cocos
# Processing Record 19 of Set 5 | fukue
# Processing Record 20 of Set 5 | ahumada
# City not found. Skipping...
# Processing Record 21 of Set 5 | souillac
# Processing Record 22 of Set 5 | shelburne
# Processing Record 23 of Set 5 | virginia beach
# Processing Record 24 of Set 5 | ravar
# Processing Record 25 of Set 5 | hirara
# Processing Record 26 of Set 5 | independence
# Processing Record 27 of Set 5 | kaitangata
# Processing Record 28 of Set 5 | japura
# Processing Record 29 of Set 5 | tirumullaivasal
# Processing Record 30 of Set 5 | cabo san lucas
# Processing Record 31 of Set 5 | tyup
# Processing Record 32 of Set 5 | amapa
# Processing Record 33 of Set 5 | klaksvik
# Processing Record 34 of Set 5 | leningradskiy
# Processing Record 35 of Set 5 | constitucion
# Processing Record 36 of Set 5 | sao gabriel da cachoeira
# Processing Record 37 of Set 5 | aranda de duero
# Processing Record 38 of Set 5 | banjar
# Processing Record 39 of Set 5 | basco
# Processing Record 40 of Set 5 | kazalinsk
# City not found. Skipping...
# Processing Record 41 of Set 5 | samsun
# Processing Record 42 of Set 5 | bulaevo
# Processing Record 43 of Set 5 | tunceli
# Processing Record 44 of Set 5 | tucson
# Processing Record 45 of Set 5 | north platte
# Processing Record 46 of Set 5 | sabha
# Processing Record 47 of Set 5 | torbay
# Processing Record 48 of Set 5 | valdivia
# Processing Record 49 of Set 5 | salta
# Processing Record 0 of Set 6 | saint anthony
# Processing Record 1 of Set 6 | san cristobal
# Processing Record 2 of Set 6 | upata
# Processing Record 3 of Set 6 | susanville
# Processing Record 4 of Set 6 | lompoc
# Processing Record 5 of Set 6 | pyay
# Processing Record 6 of Set 6 | cobourg
# Processing Record 7 of Set 6 | hamilton
# Processing Record 8 of Set 6 | ponta do sol
# Processing Record 9 of Set 6 | payo
# Processing Record 10 of Set 6 | verkhoyansk
# Processing Record 11 of Set 6 | soyo
# Processing Record 12 of Set 6 | mitsamiouli
# Processing Record 13 of Set 6 | wattegama
# Processing Record 14 of Set 6 | we
# City not found. Skipping...
# Processing Record 15 of Set 6 | kariba
# Processing Record 16 of Set 6 | thanh hoa
# Processing Record 17 of Set 6 | antofagasta
# Processing Record 18 of Set 6 | lyngseidet
# Processing Record 19 of Set 6 | changping
# Processing Record 20 of Set 6 | codrington
# Processing Record 21 of Set 6 | calama
# Processing Record 22 of Set 6 | neiafu
# Processing Record 23 of Set 6 | beloha
# Processing Record 24 of Set 6 | hualmay
# Processing Record 25 of Set 6 | egvekinot
# Processing Record 26 of Set 6 | hibbing
# Processing Record 27 of Set 6 | imeni poliny osipenko
# Processing Record 28 of Set 6 | khandbari
# Processing Record 29 of Set 6 | poso
# Processing Record 30 of Set 6 | touros
# Processing Record 31 of Set 6 | hervey bay
# Processing Record 32 of Set 6 | roebourne
# Processing Record 33 of Set 6 | sahibganj
# Processing Record 34 of Set 6 | bogande
# Processing Record 35 of Set 6 | thaba-tseka
# Processing Record 36 of Set 6 | kemin
# Processing Record 37 of Set 6 | cabedelo
# Processing Record 38 of Set 6 | comodoro rivadavia
# Processing Record 39 of Set 6 | omboue
# Processing Record 40 of Set 6 | east london
# Processing Record 41 of Set 6 | skagastrond
# City not found. Skipping...
# Processing Record 42 of Set 6 | fortuna
# Processing Record 43 of Set 6 | odweyne
# Processing Record 44 of Set 6 | saskylakh
# Processing Record 45 of Set 6 | luderitz
# Processing Record 46 of Set 6 | olinda
# Processing Record 47 of Set 6 | hartselle
# Processing Record 48 of Set 6 | iskateley
# Processing Record 49 of Set 6 | pascagoula
# Processing Record 0 of Set 7 | hobyo
# Processing Record 1 of Set 7 | cienfuegos
# Processing Record 2 of Set 7 | palabuhanratu
# City not found. Skipping...
# Processing Record 3 of Set 7 | port lincoln
# Processing Record 4 of Set 7 | mapastepec
# Processing Record 5 of Set 7 | anadyr
# Processing Record 6 of Set 7 | dire
# Processing Record 7 of Set 7 | sao filipe
# Processing Record 8 of Set 7 | buraydah
# Processing Record 9 of Set 7 | salalah
# Processing Record 10 of Set 7 | ayr
# Processing Record 11 of Set 7 | rock sound
# Processing Record 12 of Set 7 | dharmadam
# Processing Record 13 of Set 7 | fort saint james
# Processing Record 14 of Set 7 | paulo afonso
# Processing Record 15 of Set 7 | usinsk
# Processing Record 16 of Set 7 | ornskoldsvik
# Processing Record 17 of Set 7 | lusambo
# Processing Record 18 of Set 7 | marfino
# Processing Record 19 of Set 7 | trebinje
# Processing Record 20 of Set 7 | ushumun
# Processing Record 21 of Set 7 | batagay-alyta
# Processing Record 22 of Set 7 | biak
# Processing Record 23 of Set 7 | kuryk
# Processing Record 24 of Set 7 | iacu
# Processing Record 25 of Set 7 | te anau
# Processing Record 26 of Set 7 | killam
# Processing Record 27 of Set 7 | lasa
# Processing Record 28 of Set 7 | srandakan
# Processing Record 29 of Set 7 | aluksne
# Processing Record 30 of Set 7 | eskasem
# City not found. Skipping...
# Processing Record 31 of Set 7 | launceston
# Processing Record 32 of Set 7 | half moon bay
# Processing Record 33 of Set 7 | kilmez
# City not found. Skipping...
# Processing Record 34 of Set 7 | mao
# Processing Record 35 of Set 7 | bilibino
# Processing Record 36 of Set 7 | moose factory
# Processing Record 37 of Set 7 | severo-kurilsk
# Processing Record 38 of Set 7 | oxelosund
# Processing Record 39 of Set 7 | iquitos
# Processing Record 40 of Set 7 | yumen
# Processing Record 41 of Set 7 | geraldton
# Processing Record 42 of Set 7 | asau
# Processing Record 43 of Set 7 | petukhovo
# Processing Record 44 of Set 7 | rudnogorsk
# Processing Record 45 of Set 7 | tamiahua
# Processing Record 46 of Set 7 | le port
# Processing Record 47 of Set 7 | ayan
# Processing Record 48 of Set 7 | trinidad
# Processing Record 49 of Set 7 | san patricio
# Processing Record 0 of Set 8 | rungata
# City not found. Skipping...
# Processing Record 1 of Set 8 | mentok
# City not found. Skipping...
# Processing Record 2 of Set 8 | aklavik
# Processing Record 3 of Set 8 | nalut
# Processing Record 4 of Set 8 | provideniya
# Processing Record 5 of Set 8 | haines junction
# Processing Record 6 of Set 8 | mount gambier
# Processing Record 7 of Set 8 | meulaboh
# Processing Record 8 of Set 8 | san andres
# Processing Record 9 of Set 8 | kendari
# Processing Record 10 of Set 8 | lagos
# Processing Record 11 of Set 8 | sorvag
# City not found. Skipping...
# Processing Record 12 of Set 8 | berdigestyakh
# Processing Record 13 of Set 8 | varnavino
# Processing Record 14 of Set 8 | grand river south east
# City not found. Skipping...
# Processing Record 15 of Set 8 | ardakan
# Processing Record 16 of Set 8 | tondano
# Processing Record 17 of Set 8 | leshukonskoye
# Processing Record 18 of Set 8 | ponnani
# Processing Record 19 of Set 8 | balykshi
# Processing Record 20 of Set 8 | hambantota
# Processing Record 21 of Set 8 | vestbygda
# City not found. Skipping...
# Processing Record 22 of Set 8 | bintulu
# Processing Record 23 of Set 8 | kaeo
# Processing Record 24 of Set 8 | buckeye
# Processing Record 25 of Set 8 | ust-barguzin
# Processing Record 26 of Set 8 | ribeira grande
# Processing Record 27 of Set 8 | thunder bay
# Processing Record 28 of Set 8 | ambon
# Processing Record 29 of Set 8 | kahta
# Processing Record 30 of Set 8 | sampit
# Processing Record 31 of Set 8 | manono
# Processing Record 32 of Set 8 | ponta delgada
# Processing Record 33 of Set 8 | richards bay
# Processing Record 34 of Set 8 | andapa
# Processing Record 35 of Set 8 | clyde river
# Processing Record 36 of Set 8 | sobolevo
# Processing Record 37 of Set 8 | benghazi
# Processing Record 38 of Set 8 | mecca
# Processing Record 39 of Set 8 | vardo
# Processing Record 40 of Set 8 | lagoa santa
# Processing Record 41 of Set 8 | komsomolskiy
# Processing Record 42 of Set 8 | bodden town
# Processing Record 43 of Set 8 | moree
# Processing Record 44 of Set 8 | maracas
# Processing Record 45 of Set 8 | alofi
# Processing Record 46 of Set 8 | exeter
# Processing Record 47 of Set 8 | puerto colombia
# Processing Record 48 of Set 8 | riyadh
# Processing Record 49 of Set 8 | diffa
# Processing Record 0 of Set 9 | taoudenni
# Processing Record 1 of Set 9 | sansai
# City not found. Skipping...
# Processing Record 2 of Set 9 | pocone
# Processing Record 3 of Set 9 | agustin codazzi
# Processing Record 4 of Set 9 | lazaro cardenas
# Processing Record 5 of Set 9 | crotone
# Processing Record 6 of Set 9 | buqayq
# City not found. Skipping...
# Processing Record 7 of Set 9 | tuatapere
# Processing Record 8 of Set 9 | bud
# Processing Record 9 of Set 9 | arco
# Processing Record 10 of Set 9 | kimbe
# Processing Record 11 of Set 9 | flinders
# Processing Record 12 of Set 9 | labuhan
# Processing Record 13 of Set 9 | hindaun
# Processing Record 14 of Set 9 | triunfo
# Processing Record 15 of Set 9 | tiksi
# Processing Record 16 of Set 9 | fucecchio
# Processing Record 17 of Set 9 | cherskiy
# Processing Record 18 of Set 9 | one hundred mile house
# City not found. Skipping...
# Processing Record 19 of Set 9 | berlevag
# Processing Record 20 of Set 9 | elko
# Processing Record 21 of Set 9 | nyurba
# Processing Record 22 of Set 9 | simao
# Processing Record 23 of Set 9 | kepanjen
# Processing Record 24 of Set 9 | manta
# Processing Record 25 of Set 9 | nanortalik
# Processing Record 26 of Set 9 | vila velha
# Processing Record 27 of Set 9 | nhulunbuy
# Processing Record 28 of Set 9 | khash
# Processing Record 29 of Set 9 | ust-nera
# Processing Record 30 of Set 9 | ayagoz
# Processing Record 31 of Set 9 | yeppoon
# Processing Record 32 of Set 9 | sinkat
# City not found. Skipping...
# Processing Record 33 of Set 9 | tupik
# Processing Record 34 of Set 9 | erice
# Processing Record 35 of Set 9 | vaitupu
# City not found. Skipping...
# Processing Record 36 of Set 9 | minas
# Processing Record 37 of Set 9 | marcona
# City not found. Skipping...
# Processing Record 38 of Set 9 | avallon
# Processing Record 39 of Set 9 | kattivakkam
# Processing Record 40 of Set 9 | nieuw amsterdam
# Processing Record 41 of Set 9 | deputatskiy
# Processing Record 42 of Set 9 | tautira
# Processing Record 43 of Set 9 | pontes e lacerda
# Processing Record 44 of Set 9 | kahului
# Processing Record 45 of Set 9 | khotiv
# Processing Record 46 of Set 9 | iguatu
# Processing Record 47 of Set 9 | frontera
# Processing Record 48 of Set 9 | aykhal
# Processing Record 49 of Set 9 | matay
# Processing Record 0 of Set 10 | jibuti
# Processing Record 1 of Set 10 | mount isa
# Processing Record 2 of Set 10 | vila franca do campo
# Processing Record 3 of Set 10 | menongue
# Processing Record 4 of Set 10 | kungurtug
# Processing Record 5 of Set 10 | louisbourg
# City not found. Skipping...
# Processing Record 6 of Set 10 | ust-kulom
# Processing Record 7 of Set 10 | seoul
# Processing Record 8 of Set 10 | samusu
# City not found. Skipping...
# Processing Record 9 of Set 10 | toliary
# City not found. Skipping...
# Processing Record 10 of Set 10 | oda
# Processing Record 11 of Set 10 | natal
# Processing Record 12 of Set 10 | katherine
# Processing Record 13 of Set 10 | uaua
# Processing Record 14 of Set 10 | sept-iles
# Processing Record 15 of Set 10 | megion
# Processing Record 16 of Set 10 | manama
# Processing Record 17 of Set 10 | copiapo
# Processing Record 18 of Set 10 | port hardy
# Processing Record 19 of Set 10 | cabra
# Processing Record 20 of Set 10 | gat
# Processing Record 21 of Set 10 | ceres
# Processing Record 22 of Set 10 | puerto escondido
# Processing Record 23 of Set 10 | kipini
# Processing Record 24 of Set 10 | bandar-e lengeh
# Processing Record 25 of Set 10 | faanui
# Processing Record 26 of Set 10 | petropavl
# Processing Record 27 of Set 10 | savannah bight
# Processing Record 28 of Set 10 | yegros
# Processing Record 29 of Set 10 | jacareacanga
# Processing Record 30 of Set 10 | linqing
# Processing Record 31 of Set 10 | kirakira
# Processing Record 32 of Set 10 | chissamba
# Processing Record 33 of Set 10 | guerrero negro
# Processing Record 34 of Set 10 | dwarka
# Processing Record 35 of Set 10 | katsuura
# Processing Record 36 of Set 10 | sakakah
# Processing Record 37 of Set 10 | ust-kut
# Processing Record 38 of Set 10 | dubbo
# Processing Record 39 of Set 10 | dauphin
# Processing Record 40 of Set 10 | ormara
# Processing Record 41 of Set 10 | faratsiho
# Processing Record 42 of Set 10 | lac-megantic
# Processing Record 43 of Set 10 | carahue
# Processing Record 44 of Set 10 | oussouye
# Processing Record 45 of Set 10 | gazli
# Processing Record 46 of Set 10 | kushima
# Processing Record 47 of Set 10 | ambilobe
# Processing Record 48 of Set 10 | broome
# Processing Record 49 of Set 10 | stony brook
# Processing Record 0 of Set 11 | belmonte
# Processing Record 1 of Set 11 | halalo
# City not found. Skipping...
# Processing Record 2 of Set 11 | zaterechnyy
# Processing Record 3 of Set 11 | tarudant
# City not found. Skipping...
# Processing Record 4 of Set 11 | bonavista
# Processing Record 5 of Set 11 | fort wellington
# Processing Record 6 of Set 11 | ketchikan
# Processing Record 7 of Set 11 | yazykovo
# Processing Record 8 of Set 11 | cody
# Processing Record 9 of Set 11 | mehamn
# Processing Record 10 of Set 11 | koumac
# Processing Record 11 of Set 11 | olafsvik
# Processing Record 12 of Set 11 | vostok
# Processing Record 13 of Set 11 | salto
# Processing Record 14 of Set 11 | ejura
# Processing Record 15 of Set 11 | mbour
# Processing Record 16 of Set 11 | nioro
# Processing Record 17 of Set 11 | ust-tsilma
# Processing Record 18 of Set 11 | gabi
# Processing Record 19 of Set 11 | saint-pierre
# Processing Record 20 of Set 11 | ewa beach
# Processing Record 21 of Set 11 | santa cruz
# Processing Record 22 of Set 11 | sahbuz
# Processing Record 23 of Set 11 | moreira sales
# Processing Record 24 of Set 11 | alta gracia
# Processing Record 25 of Set 11 | samarai
# Processing Record 26 of Set 11 | vestmannaeyjar
# Processing Record 27 of Set 11 | yatou
# Processing Record 28 of Set 11 | izhma
# Processing Record 29 of Set 11 | atambua
# Processing Record 30 of Set 11 | chernyshevskiy
# Processing Record 31 of Set 11 | svetlaya
# Processing Record 32 of Set 11 | port hedland
# Processing Record 33 of Set 11 | opunake
# Processing Record 34 of Set 11 | chicama
# Processing Record 35 of Set 11 | magadan
# Processing Record 36 of Set 11 | santa rosa
# Processing Record 37 of Set 11 | havelock
# Processing Record 38 of Set 11 | morrinhos
# Processing Record 39 of Set 11 | lingao
# Processing Record 40 of Set 11 | el limon
# Processing Record 41 of Set 11 | karpogory
# Processing Record 42 of Set 11 | lima
# Processing Record 43 of Set 11 | taneatua
# City not found. Skipping...
# Processing Record 44 of Set 11 | acapulco
# Processing Record 45 of Set 11 | gombe
# Processing Record 46 of Set 11 | miyako
# Processing Record 47 of Set 11 | stoyba
# City not found. Skipping...
# Processing Record 48 of Set 11 | juneau
# Processing Record 49 of Set 11 | grand centre
# City not found. Skipping...
# Processing Record 0 of Set 12 | moyale
# Processing Record 1 of Set 12 | nador
# Processing Record 2 of Set 12 | lindi
# Processing Record 3 of Set 12 | vuktyl
# Processing Record 4 of Set 12 | bandarbeyla
# Processing Record 5 of Set 12 | coquimbo
# Processing Record 6 of Set 12 | nampula
# Processing Record 7 of Set 12 | kalmunai
# Processing Record 8 of Set 12 | opotiki
# Processing Record 9 of Set 12 | omsukchan
# Processing Record 10 of Set 12 | eyl
# Processing Record 11 of Set 12 | bull savanna
# Processing Record 12 of Set 12 | nuuk
# Processing Record 13 of Set 12 | morondava
# Processing Record 14 of Set 12 | portland
# Processing Record 15 of Set 12 | bucerias
# Processing Record 16 of Set 12 | sur
# Processing Record 17 of Set 12 | zolotkovo
# Processing Record 18 of Set 12 | poronaysk
# Processing Record 19 of Set 12 | barawe
# City not found. Skipping...
# Processing Record 20 of Set 12 | tsybli
# Processing Record 21 of Set 12 | kamenskoye
# City not found. Skipping...
# Processing Record 22 of Set 12 | manaus
# Processing Record 23 of Set 12 | oranjestad
# Processing Record 24 of Set 12 | otukpo
# Processing Record 25 of Set 12 | adrar
# Processing Record 26 of Set 12 | pizarro
# Processing Record 27 of Set 12 | ruangwa
# Processing Record 28 of Set 12 | leh
# Processing Record 29 of Set 12 | maragogi
# Processing Record 30 of Set 12 | oranjemund
# Processing Record 31 of Set 12 | erzin
# Processing Record 32 of Set 12 | merauke
# Processing Record 33 of Set 12 | sindor
# Processing Record 34 of Set 12 | yar-sale
# Processing Record 35 of Set 12 | lac du bonnet
# Processing Record 36 of Set 12 | port elizabeth
# Processing Record 37 of Set 12 | longhua
# Processing Record 38 of Set 12 | maceio
# Processing Record 39 of Set 12 | chapais
# Processing Record 40 of Set 12 | akhmim
# Processing Record 41 of Set 12 | mandalgovi
# Processing Record 42 of Set 12 | maputo
# Processing Record 43 of Set 12 | tanout
# Processing Record 44 of Set 12 | totolapa
# Processing Record 45 of Set 12 | komsomolets
# Processing Record 46 of Set 12 | killybegs
# Processing Record 47 of Set 12 | luganville
# Processing Record 48 of Set 12 | pringsewu
# Processing Record 49 of Set 12 | lipari
# Processing Record 0 of Set 13 | zelenets
# Processing Record 1 of Set 13 | ancud
# Processing Record 2 of Set 13 | serenje
# Processing Record 3 of Set 13 | caqueza
# Processing Record 4 of Set 13 | nioki
# Processing Record 5 of Set 13 | pinega
# Processing Record 6 of Set 13 | fulitun
# City not found. Skipping...
# Processing Record 7 of Set 13 | nikolskiy
# Processing Record 8 of Set 13 | karachev
# Processing Record 9 of Set 13 | namibe
# Processing Record 10 of Set 13 | novoukrayinka
# Processing Record 11 of Set 13 | wonji
# City not found. Skipping...
# Processing Record 12 of Set 13 | yulara
# Processing Record 13 of Set 13 | lorengau
# Processing Record 14 of Set 13 | shieli
# Processing Record 15 of Set 13 | ixtapa
# Processing Record 16 of Set 13 | taltal
# Processing Record 17 of Set 13 | nome
# Processing Record 18 of Set 13 | meyungs
# City not found. Skipping...
# Processing Record 19 of Set 13 | sarkand
# Processing Record 20 of Set 13 | bowen
# Processing Record 21 of Set 13 | wanning
# Processing Record 22 of Set 13 | noumea
# Processing Record 23 of Set 13 | north bend
# Processing Record 24 of Set 13 | makat
# Processing Record 25 of Set 13 | freeport
# Processing Record 26 of Set 13 | havoysund
# Processing Record 27 of Set 13 | vryburg
# Processing Record 28 of Set 13 | goderich
# Processing Record 29 of Set 13 | lasem
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the cities weather data into a Pandas DataFrame
city_data_df = pd.DataFrame(city_data)

# Show Record Count
city_data_df.count()
# Out:
# City          578
# Lat           578
# Lng           578
# Max Temp      578
# Humidity      578
# Cloudiness    578
# Wind Speed    578
# Country       578
# Date          578
# dtype: int64

# %%
# Display sample data
city_data_df.head()
# Out:
#            City      Lat      Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0       urucara  -2.5364 -57.7600     24.79        91          70        0.73
# 1       ushuaia -54.8000 -68.3000      4.81        75          20       10.80
# 2        albany  42.6001 -73.9662     20.51        78         100        1.34
# 3      cidreira -30.1811 -50.2056      9.04        71          83        3.65
# 4  punta arenas -53.1500 -70.9167      6.06        70          20        6.17
#
#   Country        Date
# 0      BR  1686624372
# 1      AR  1686624372
# 2      US  1686624110
# 3      BR  1686624338
# 4      CL  1686624177

# %%
# Export the City_Data into a csv
city_data_df.to_csv("../output_data/cities.csv", index_label="City_ID")

# %%
# Read saved data
city_data_df = pd.read_csv("../output_data/cities.csv", index_col="City_ID")

# Display sample data
city_data_df.head()
# Out:
#                  City      Lat      Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0             urucara  -2.5364 -57.7600     24.79        91          70
# 1             ushuaia -54.8000 -68.3000      4.81        75          20
# 2              albany  42.6001 -73.9662     20.51        78         100
# 3            cidreira -30.1811 -50.2056      9.04        71          83
# 4        punta arenas -53.1500 -70.9167      6.06        70          20
#
#          Wind Speed Country        Date
# City_ID
# 0              0.73      BR  1686624372
# 1             10.80      AR  1686624372
# 2              1.34      US  1686624110
# 3              3.65      BR  1686624338
# 4              6.17      CL  1686624177

# %% [markdown]
# ### Create the Scatter Plots Requested
#
# #### Latitude Vs. Temperature

# %%
# Build scatter plot for latitude vs. temperature
plt.scatter(
    city_data_df["Lat"],
    city_data_df["Max Temp"],
    edgecolor="red",
    linewidths=1,
    marker="o",
    alpha=0.8,
    label="Cities"
    


)

# Incorporate the other graph properties
date= time.strftime("%Y-%m-%d")
plt.title(f"City Max Latitude vs. Temperature ({date})")
plt.xlabel("Latitude")
plt.ylabel("Max Temp (C)")

# Save the figure
plt.savefig("../output_data/Fig1.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Humidity

# %%
# Build the scatter plots for latitude vs. humidity
plt.scatter(
    city_data_df["Lat"],
    city_data_df["Humidity"],
    edgecolor="green",
    linewidths=1,
    marker="o",
    alpha=0.8,
    label="Cities"
    


)
# Incorporate the other graph properties
date= time.strftime("%Y-%m-%d")
plt.title(f"City Max Latitude vs. Humidity ({date})")
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")

# Save the figure
plt.savefig("../output_data/Fig2.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
# Build the scatter plots for latitude vs. cloudiness
plt.scatter(
    city_data_df["Lat"],
    city_data_df["Cloudiness"],
    edgecolor="orange",
    linewidths=1,
    marker="o",
    alpha=0.8,
    label="Cities"
    


)

# Incorporate the other graph properties
date= time.strftime("%Y-%m-%d")
plt.title(f"City Max Latitude vs. Cloudiness ({date})")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")


# Save the figure
plt.savefig("../output_data/Fig3.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build the scatter plots for latitude vs. wind speed
plt.scatter(
    city_data_df["Lat"],
    city_data_df["Wind Speed"],
    edgecolor="purple",
    linewidths=1,
    marker="o",
    alpha=0.8,
    label="Cities"
    


)
# Incorporate the other graph properties
date= time.strftime("%Y-%m-%d")
plt.title(f"City Max Latitude vs. Wind Speed ({date})")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (%)")

# Save the figure
plt.savefig("../output_data/Fig4.png")

# Show plot
plt.show()

# %% [markdown]
# ---
#
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %%
# Define a function to create Linear Regression plots
# YOUR CODE HERE
def plot_linear_regression(x_value, y_value,title, text_coord):
    
    
    #compute linear regression
    (slope,intercept,rvalue,pvalue,stdeer)= linregress(x_value,y_value)
    regress_value = x_value * slope + intercept
    line_eq = f"y = {round(slope,2)}x + {round(intercept,2)}"
    
    plt.scatter(x_value, y_value)
    plt.plot(x_value, regress_value, "r-")
    plt.annotate(line_eq, text_coord, fontsize=15, color="red")
    plt.xlabel("Lat")
    plt.ylabel(title)
    print(f"The r-value is{rvalue **2}")
    plt.show

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
northern_hemi_df = city_data_df[city_data_df["Lat"]>=0]

# Display sample data
northern_hemi_df.head()
# Out:
#                       City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 2                   albany  42.6001  -73.9662     20.51        78         100
# 7                  iqaluit  63.7506  -68.5145      0.85        69          75
# 8                   barrow  71.2906 -156.7887      7.01        76           0
# 9              yellowknife  62.4560 -114.3525      7.29        70          75
# 13       riviere-au-renard  48.9957  -64.3971     11.16        69          53
#
#          Wind Speed Country        Date
# City_ID
# 2              1.34      US  1686624110
# 7              4.63      CA  1686624372
# 8              4.12      US  1686624372
# 9              3.09      CA  1686624097
# 13             1.81      CA  1686624258

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
southern_hemi_df = city_data_df[city_data_df["Lat"]<0]

# Display sample data
southern_hemi_df.head()
# Out:
#                  City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0             urucara  -2.5364  -57.7600     24.79        91          70
# 1             ushuaia -54.8000  -68.3000      4.81        75          20
# 3            cidreira -30.1811  -50.2056      9.04        71          83
# 4        punta arenas -53.1500  -70.9167      6.06        70          20
# 5               vaini -21.2000 -175.2000     23.09        78          75
#
#          Wind Speed Country        Date
# City_ID
# 0              0.73      BR  1686624372
# 1             10.80      AR  1686624372
# 3              3.65      BR  1686624338
# 4              6.17      CL  1686624177
# 5              0.51      TO  1686624372

# %% [markdown]
# ###  Temperature vs. Latitude Linear Regression Plot

# %%
# Linear regression on Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Max Temp"]
plot_linear_regression(x_values, y_values, "Max Temp", (6,-10))
# Out:
# The r-value is0.6556434526145274

# %%
# Linear regression on Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Max Temp"]
plot_linear_regression(x_values, y_values, "Max Temp", (-55,5))
# Out:
# The r-value is0.5549205413717472

# %% [markdown]
# **Discussion about the linear relationship:** Temperature progressivey decrease the further you get from the equator.

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Humidity"]
plot_linear_regression(x_values, y_values, "Humidity", (50,20))
# Out:
# The r-value is0.002427677043851514

# %%
# Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Humidity"]
plot_linear_regression(x_values, y_values, "Humidity", (-50,30))
# Out:
# The r-value is0.021204108430033026

# %% [markdown]
# **Discussion about the linear relationship:** The closer you get to the equater, the temperture gradually increases

# %% [markdown]
# ### Cloudiness vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
# YOUR CODE HERE
colour_cloud = 'cornflowerblue'
north_cloud = northern_hemi_df['Cloudiness']
north_slope_cloud, north_int_cloud, north_r_cloud, north_p_cloud, north_std_err_cloud = plot_linear_regression(north_x, north_cloud)
north_cloud_regress = north_slope_cloud*north_x + north_int_cloud
north_cloud_slope_display = round(north_slope_cloud, 2)
north_cloud_int_display = round(north_int_cloud, 2)
cloud_eq_display = f"{north_cloud_slope_display}x + {north_cloud_int_display}"

plt.scatter(north_x, north_cloud, c=colour_cloud)
plt.xlabel('Latitude')
plt.ylabel('Cloudiness')
plt.title('Northern Hemisphere Latitude vs. Cloudiness')
plt.plot(north_x, north_cloud_regress, color='red')
plt.annotate(cloud_eq_display, (40,20), fontsize=15, color='blue')
plt.show()
print(f'The r-value for the Cloudiness in the NH: {north_r_cloud**2}.')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/yr/mvbgq8nd3px65zgs8fcfmmk00000gn/T/ipykernel_11893/3416616329.py in <module>
#       3 colour_cloud = 'cornflowerblue'
#       4 north_cloud = northern_hemi_df['Cloudiness']
# ----> 5 north_slope_cloud, north_int_cloud, north_r_cloud, north_p_cloud, north_std_err_cloud = line_regression(north_x, north_cloud)
#       6 north_cloud_regress = north_slope_cloud*north_x + north_int_cloud
#       7 north_cloud_slope_display = round(north_slope_cloud, 2)
#
# NameError: name 'line_regression' is not defined

# %%
# Southern Hemisphere
# YOUR CODE HERE

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Wind Speed vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
# YOUR CODE HERE

# %%
# Southern Hemisphere
# YOUR CODE HERE

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE
